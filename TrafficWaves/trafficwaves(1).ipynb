# %% [markdown]
# #**Traffic Waves**
#
# Grupo: Kevin, Lucas e Mateus \\
# Curso: Métodos Computacionais da Física C (2021/1)

# %% [markdown]
# ####**Introdução:**
# Da mecânica de fluidos, podemos escrever uma equação de movimento tal que:
# <br>
# #$$\frac{\partial \rho}{\partial t} = - \nabla \cdot Q(\rho) \tag{1}$$
# <center>
# tal que $\rho$ é uma densidade (massa, energia ou momentum) e $Q(\rho)$ é um fluxo (massa, energia ou momentum).
# </center>
# <br>
# Considerando apenas uma dimensão ($x$) temos que (1) torna-se:
# <br>
# $$\frac{\partial \rho}{\partial t} = - \frac{\partial}{\partial x}Q(\rho) \tag{2}$$
# <br>

# %% [markdown]
# A equação (2) acima, quando no contexto de densidade $\rho$ e fluxo $Q$ de massa, recai sobre a já conhecida equação da continuidade, na qual $\rho$ é uma função da posição ($x$) e do tempo ($t$): $\rho(x,t)$; o fluxo de massa pode ser dado em função de $\rho$ e $v$ tal que: $Q=\rho v$. Onde $v$ é a velocidade associada a massa e pode ser escrita em função de $x$ e $t$: $v(x,t)$. Temos então que (2) torna-se:
# <br>
# #$$\frac{\partial}{\partial t}\rho(x,t) = - \frac{\partial}{\partial x}\bigg[ \rho(x,t) v(x,t)\bigg] \tag{3}$$

# %% [markdown]
# ####**Trânsito de Veículos:**
#
# Vamos aproximar o trânsito de veículos em uma faixa única e sem ultrapassagens, define-se então as seguintes propriedades desta faixa:
# <center>
# $\rho(x,t) \equiv $   densidade (carros/km) $\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;\;(4.1)$  <br>
# $v(\rho) \equiv $   velocidade dos carros (km/hora) $\;\;\;\;\;\;\;\;\;(4.2)$<br>
# $q(x,t)  \equiv$ fluxo de carros (carros/hora) $\;\;\;\;\;\;\;\;\;\;\;(4.3)$
# </center>
# Nota-se que, diferentemente de (3), na equação (4.2), a velocidade depende apenas de $\rho$ e então, da equação (4.3) podemos escrever a relação entre o fluxo de carros, a densidade e a velocidade de uma região desta faixa na forma de:
# $$q=\rho v \tag{4.5}$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center>Fig. 1 - Ilustração das definições de densidade e velocidade dos veículos na faixa </center>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <center> Fig. 2 - Ilustraçao do conceito de fluxo de carros, calculado a partir da quantidade de carros que passam em uma determinada região em função de um tempo $t$</center>

# %% [markdown]
# Ainda nesta mesma faixa $x$, sabe-se que a quantidade de carros ($n$) dentro de um intervalo $[x, x+\Delta x]$ é dada pela integral da função densidade $\rho$ tal que:
# <br>
#  $$\int_{x}^{x+ \Delta x} \rho(x,t) dx = n \tag{5}$$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Porém, quando analisamos  a taxa temporal com a qual (5) varia no tempo, faz-se possível a seguinte dedução:
# #$$ \partial t \int_{x}^{x+ \Delta x} \rho(x,t) dx = q(x)-q(x+\Delta x)\tag{6} $$
# Uma vez que (6) se dá ao fato de que a quantidade de carros no intervalo $[x, x+\Delta x]$ vai depender apenas do fluxo de carros que está "entrando" em $x$  e do fluxo de carros que estão "saindo" em $x+\Delta x$. Pode-se fazer a comparação com a função de conservação de massa já conhecida, uma vez que estamos considerando que não existem carros surgindo e sendo destruídos, a quantidade de massa (carros) total em um determinado $t_0$, deve ser a mesma  que em outro $t_0+\Delta t$.

# %% [markdown]
# Tomando o limite com $\Delta x \to 0$ em (6), temos:
# #$$ lim_{\Delta x \to 0} \; \partial t \int_{x}^{x+ \Delta x} \rho(x,t) dx = q(x)-q(x+\Delta x) \Longrightarrow \partial t [\Delta x \rho(x,t)]=\frac{q(x)-q(x + \Delta x)}{\Delta x} \tag{7}$$

# %% [markdown]
# Segue-se então,
# ##$$ \partial t [\Delta x \rho(x,t)]=\frac{q(x)-q(x + \Delta x)}{\Delta x} \Longrightarrow \frac{\partial \rho}{\partial t} = -\frac{\partial q}{\partial t}  \tag{8}$$
# Nota-se então que, como $q = \rho(x,t)v(\rho)$ uma vez que estmamos considerando que a velocidade $v$ depende apenas da densidade, podemos escrever, a partir de (8) a seguinte equação:
# ##$$ \frac{\partial \rho}{\partial t} = -\frac{\partial q}{\partial t}  \tag{9} \Longrightarrow \frac{\partial }{\partial t}\rho(x,t) = - \frac{\partial }{\partial x} \rho(x,t)v(\rho)$$
# Temos assim que, apesar da aproximação na função da velocidade citada anteriormente, (9) é uma equação da continuidade assim como (3) porém para a quantidade de carros e não de massa. Com isso, validamos nossa modelagem do trânsito de veículos.

# %% [markdown]
# ####**Análise do Problema Não-Linear**
# Como $v$ é uma função de $\rho$, com a regra da cadeia, pode-se reescrever a equação (9) de maneira que seja possível tratar o problema apenas em função de $\rho$, já que não temos ainda uma expressão para a função $v(\rho)$; segue-se então:
# ##$$ \frac{\partial}{\partial t}\rho + \frac{\partial}{\partial x}v(\rho)\rho = 0 \Longrightarrow  \frac{\partial}{\partial t}\rho + \frac{\partial \rho}{\partial x}\bigg[v'(\rho)\rho\;+\;v(\rho)\bigg] \therefore \frac{\partial \rho}{\partial t} + c(\rho)\frac{\partial \rho}{\partial x} = 0 \tag{10}$$
# Com $c(\rho) = v'(\rho)\rho\;+\;v(\rho)$ para simplificarmos a notação.

# %% [markdown]
# Para conseguirmos analisar este problema precisamos definir o que vamos considerar de $v(\rho)$. Neste problema tratado aqui, vamos fazer as seguintes imposições:
# <br>
# > Com $\rho = 0 \longrightarrow v(\rho) = v_o$ (limite de velocidade da faixa);
# <br>
# > Com $\rho = \rho_{max} \longrightarrow v(\rho) = 0$ (Congestionamento total da faixa.
#
# Considerando uma relação linear entre $v$ e $\rho$ a partir das imposíções acima,temos a seguinte relação:
# #$$ v = \frac{v_o}{\rho_{max}}\big(\rho_{max}-\rho\big) \tag{11}$$

# %%
#@title 
import matplotlib.pyplot as plt
import numpy as np
import math

rho_max = 1
rho_min = 0
vo = 1

def v(rho):
  return (vo/rho_max)*(rho_max-rho)

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)

rho = np.linspace(rho_min, rho_max, 100)
plt.xticks(ticks = [0,1], labels=[r'$\rho_{min}$', r'$\rho_{max}$'])
plt.yticks(ticks = [0,1], labels=[0, r'$v_o$'])
plt.title(r'Gráfico da funçao $v(\rho)$', fontsize=30)
plt.ylabel(r'$v$', fontsize=20, rotation=0)
plt.xlabel(r'$\rho$', fontsize=20)
plt.plot(rho, v(rho), lw=3, label=r'$v(\rho)$')
plt.legend(fontsize=20)



plt.show()

# %% [markdown]
# <center> Fig. 3 - Gráfico da função $v(\rho)$ a partir da expressão 11. </center>

# %% [markdown]
# Partindo de (11), podemos construir uma equação para $q$ tal que:
# #$$ q = \rho v = \rho \bigg[\frac{v_o}{\rho_{max}}\big(\rho_{max}-\rho\big)\bigg] \tag{12}$$

# %%
#@title 
rho_max = 1
rho_min = 0
vo = 1

def q(rho):
  return 2*(vo/rho_max)*rho*(rho_max-rho)

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)

rho = np.linspace(rho_min, rho_max, 100)
plt.xticks(ticks = [0,1/2,1], labels=[r'$\rho_{min}$',r'$\frac{1}{2}\rho_{max}$', r'$\rho_{max}$'])
plt.yticks(ticks = [0,1/2], labels=[0, r'$\frac{1}{2}v_o$'])
plt.title(r'Gráfico da funçao $q$', fontsize=30)
plt.ylabel(r'$v$', fontsize=20, rotation=0)
plt.xlabel(r'$\rho$', fontsize=20)
plt.plot(rho, q(rho), lw=3, label=r'$q(v_o,\rho)$', c='green')
plt.ylim(0,1/2+0.1)
plt.legend(fontsize=20)



plt.show()

# %% [markdown]
# <center> Fig. 4 - Gráfico da função do fluxo. Pode-se perceber que o fluxo tem seu máximo quando $v=\frac{v_o}{2}$ e $\rho = \frac{rho_{max}}{2}$.</center>

# %% [markdown]
# Precisamos analisar o que acontece com o termo $c(\rho)$ a partir das definições de (11) e (12).

# %%
#@title 
rho_max = 1
rho_min = 0
vo = 1

def c(rho):
  return (vo/rho_max)*(rho_max-2*rho)

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)

rho = np.linspace(rho_min, rho_max, 100)
plt.xticks(ticks = [0,1/2,1], labels=[r'$\rho_{min}$',r'$\frac{1}{2}\rho_{max}$', r'$\rho_{max}$'])
plt.yticks(ticks = [-1,0,1], labels=[r'$-v_o$',0, r'$v_o$'])
plt.title(r'Gráfico da funçao $c$', fontsize=30)
plt.ylabel(r'$v$', fontsize=20, rotation=0)
plt.xlabel(r'$\rho$', fontsize=20)
plt.plot(rho, c(rho), lw=3, label=r'$c(v_o,\rho)$', c='orange')
#plt.ylim(0,1/2+0.1)
plt.legend(fontsize=20)



plt.show()

# %% [markdown]
# <center>Fig. 5 - Gráfico da perturbação $c(\rho)$ do trânsito.</center>

# %% [markdown]
# Analisando os três observáveis em conjunto temos o seguinte gráfico:

# %%
#@title 
rho_max = 1
rho_min = 0
vo = 1

def c(rho):
  return (vo/rho_max)*(rho_max-2*rho)

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(0)
ax.spines['top'].set_linewidth(0)

rho = np.linspace(rho_min, rho_max, 100)
plt.xticks(ticks = [0,1/2,1], labels=[r'$\rho_{min}$',r'$\frac{1}{2}\rho_{max}$', r'$\rho_{max}$'])
plt.yticks(ticks = [-1,0,1], labels=[r'$-v_o$',0, r'$v_o$'])
plt.title(r'Gráfico da funções $c(\rho)$, $q(\rho)$ e $v(\rho)$', fontsize=30)
plt.ylabel(r'$v$', fontsize=20, rotation=0)
plt.xlabel(r'$\rho$', fontsize=20)
plt.plot(rho, c(rho), lw=3, label=r'$c(v_o,\rho)$', c='orange')
plt.plot(rho, q(rho), lw=3, label=r'$q(v_o,\rho)$', c='green')
plt.plot(rho, v(rho), lw=3, label=r'$v(\rho)$')
plt.hlines(y=0, xmax=1, xmin=-1, ls='--', colors='k')
plt.xlim(-0.001,1)
#plt.ylim(0,1/2+0.1)
plt.legend(fontsize=20)



plt.show()

# %% [markdown]
# <center>Fig. 6 - Gráfico das três funções.</center>

# %% [markdown]
# No gráfico acima (Fig. 6) existem 2 importantes pontos: <br>
# > $i \;-\; $ Como $q$ tem seu pico em $\frac{\rho_{max}}{2}$, percebemos que a melhor velocidade para os carros transitarem na faixa é $\frac{v_o}{2}$, com $v_o$ sendo o limite de velocidade da faixa em questão. <br>
# > $ii \;-\; $ $c(\rho)$ é a perturbação no trânsito causada pelo aumento da densidade $\rho$. Nota-se que, $c(\rho)>0$ para $\rho <\frac{\rho_{max}}{2}$ e $c(\rho)<0$ para $\rho >\frac{\rho_{max}}{2}$. O que deixa e entender que $c(\rho)$ está relacionada ao surgimento de seções de congestionamento na faixa.

# %% [markdown]
# ####**Solução Analítica - Problema do Valor Inicial**

# %% [markdown]
# Desejamos resolver o seguinte problema em questão:
#
# #$$\frac{\partial \rho}{\partial t} + c(\rho)\frac{\partial \rho}{\partial x} = 0$$
#
# Sendo as condições iniciais do problema tais que:
#
# $$\rho (x,0) = \rho _0 (x)$$
#
# Com foco nas curvas caracteristicas, se desejarmos $\rho (X(t),t) = const.$ então:
#
# #$$\frac{d}{dt}\rho (X(t),t) = \frac{dX}{dt}\frac{\partial \rho}{\partial x} + \frac{\partial \rho}{\partial t} = 0$$
#
# Pelas definições já feitas, obtemos que:
#
# #$$\frac{dX}{dt} = c(\rho)$$
#
# As linhas caracteristicas são portanto retas com inclinação dada por $c(\rho _0 (x_0))$, a equação geral é portanto:
#
# #$$X(t) = x_0 + c(\rho _0 (x_0))t$$
#
# Não podemos escrever uma solução para o problema inicial mas é possível constatar:
#
# #$$\rho (x_0 + c(\rho _0 (x_0))t, t) = \rho _0 (x_0)$$
#
# É possível portanto calcular a solução adiante do tempo dado as condições iniciais do problema mas não o contrário (tendo apenas x e t) pois não temos informações sobre $c(\rho _0 (x_0))$ salvo sabendo as condições iniciais do problema.

# %%
def disposition(x):
  return 0.5*(1-math.tanh(x))

x_space = np.linspace(-5,5,200)
disposition_x = np.vectorize(disposition)
po = disposition_x(x_space)

# %% [markdown]
# Considerando o caso em que não choque:
# #$$\rho _{max} = v_0 = 1$$
# E as condições de contorno são tais que:
# #$$\rho _0 = \frac{1 - tanh(x)}{2}$$

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
plt.plot(x_space,po, lw=3)
plt.xlabel(r"$X(0)$", fontsize=20)
plt.ylabel(r"$\rho_o$", fontsize=20)
plt.show()
# Out:
# Text(0, 0.5, '$\\rho_o$')

# %% [markdown]
# Considerando a função "c" como:
# ##$$c(\rho) = v_0 \frac{\rho _{max} - 2\rho}{\rho _{max}} \therefore c_0(\rho) = c(\rho = \rho_0) = 1 - 2\rho_0$$

# %%
co = (-2*po) + 1 

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)

plt.plot(x_space,co, lw=3)
plt.xlabel(r"$X(0)$", fontsize=20)
plt.ylabel(r"$\rho_o$", fontsize=20)
plt.show()
# Out:
# Text(0, 0.5, '$\\rho_o$')

# %% [markdown]
# Visualizando as curvas caracteristicas, ou seja, as retas que mostram a evolução de X em função do tempo.

# %%
def linear_x(xo,t):
  def c(x):
    return math.tanh(x)
  return xo + c(xo)*t

t_space = np.linspace(0,5,6)
x_sample = np.linspace(-3,3,9)
linear_exp_x = np.vectorize(linear_x)


fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)

for x in x_sample:
  plt.plot(t_space, linear_exp_x(x, t_space), lw=3)
plt.xlabel("Tempo", fontsize=20)
plt.ylabel(r"$X(t)$", fontsize=20)
plt.show()
# Out:
# Text(0, 0.5, '$X(t)$')

# %% [markdown]
# Visualizando a evolução temporal da função $\rho (x,t)$

# %%
fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)
for time in t_space:
  x = linear_exp_x(x_space,time)
  plt.plot(x_space,disposition_x(x), lw=3)

plt.xlim(-2,2)
plt.ylabel("P(x,t)")
plt.xlabel("X(t)")
plt.show()

# %% [markdown]
# ####**Resolução via FTCS**

# %% [markdown]
# Partimos nossa análise da equação da continuidade:
# #$$\frac{\partial}{\partial t}\rho (x,t) = -\frac{\partial}{\partial x}Q
# (\rho)$$
#
# #$$F(\rho) = \rho (x,t)v(\rho (x,t))$$
#
# #$$v(\rho) = v_m(1 - \rho/\rho_{max})$$
#
# O método LTCS nos dá a solução tal que:
#
# #$$\rho^{n+1}_{i} = \rho^{n}_i - \frac{\tau}{2h}(F^{n}_{i+1} - F^{n}_{i-1})$$
#
# Para o caso initial:
#
# #$$\rho _0 = \frac{1 - tanh(x)}{2}$$

# %%
def initial_p(x):
  return 0.5*(1-math.tanh(x))

def f_p(p):
  return p*(1-p)

x_space = np.linspace(-50,100,200)
t_space = np.linspace(0,50,51)
acumulate_values = np.zeros((t_space.shape[0],x_space.shape[0]))

set_initial_p = np.vectorize(initial_p)

po = set_initial_p(x_space)

fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)

for time in range(0,t_space.shape[0]):
  p = po
  for position in range(0,p.shape[0]-1):
    p[position] = po[position] - 0.5*(f_p(p[position+1]) - f_p(p[position-1]))
  po = p
  acumulate_values[time] = p
  plt.plot(x_space,p, lw=3)
plt.xlabel(r"$x(t)$", fontsize=20)
plt.ylabel(r"$\rho(x,t)$", fontsize=20)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.tick_params(axis="z", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)


for j in range(acumulate_values.shape[0]):
    ys = j*np.ones(acumulate_values.shape[1])
    ax.plot(x_space, ys, acumulate_values[j,:], lw=3)

ax.set_xlabel(r"$x$", fontsize=20)
ax.set_ylabel(r"$t$", fontsize=20)
ax.set_zlabel(r"$\rho(x,t)$", fontsize=20, rotation=0)
plt.xticks([-40,0,100])
plt.yticks([0,20,40])


plt.show()

# %% [markdown]
# ####**Choque**
# Considere duas linhas características
#
# $$X_0(t) = x_0 + c(\rho _0 (x_0))t$$
#
# $$X_1(t) = x_0 +\delta x + c(\rho _0 (x_0 + \delta x))t$$
#
# Onde $ \delta > 0  $. Estamos interessados no caso em que
# $$X_0(t) = X_1(t)$$
# $$ x_0 + c(\rho _0 (x_0))t =  x_0 +\delta x + c(\rho _0 (x_0 + \delta x))t$$
#
# $$ c(\rho _0 (x_0))t =  \delta x + c(\rho _0 (x_0 + \delta x))t$$
#
# $$ t \delta x=c(\rho _0 (x_0)) - c(\rho _0 (x_0 + \delta x))$$
# $$ t = -1 / c'(x)$$
#
# Se $c'(x)$ >0 $ para todo x pertencente ao domínio, as linhas não se intersectam. Caso contrário, haverão pontos onde a função é multivalorada.

# %% [markdown]
# Exemplo: 0.5*(1 + tanhx)

# %%
import numpy as np
import matplotlib.pyplot as plt
import math

def linear_x(xo,t):
  def c(x):
    return -math.tanh(x)
  return xo + c(xo)*t

t_space = np.linspace(0,5,5)
x_sample = np.linspace(-6,6,15)
linear_exp_x = np.vectorize(linear_x)


fig, ax = plt.subplots(figsize=(16,9))

ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)
ax.spines['top'].set_linewidth(2)

for x in x_sample:
  plt.plot(t_space, linear_exp_x(x, t_space), lw=3)
plt.xlabel("Tempo", fontsize=20)
plt.ylabel(r"$X(t)$", fontsize=20)
plt.show()

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

N = 80        #Grid points
L = 400.      # System size (meters)
h = L/N       # Grid spacing for periodic boundary conditions
v_max = 25.   # Maximum car speed (m/s)
tau = 0.1
nstep = 40
coeff = tau/(2*h) 
xs = np.arange (0, 80, 1)

rho_max = 1.0                   # Maximum density
Flow_max = 0.25*rho_max*v_max   # Maximum Flow
Flow = np.empty(N)
cp = np.empty(N);  cm = np.empty(N)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho[i] = rho_max     # Max density in the square pulse

rho[int(N/2)] = rho_max/2   # Try running without this line


fig, ax = plt.subplots(figsize=(16,9))
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Periodic boundary
ip = np.arange(N) + 1  
ip[N-1] = 0          # ip = i+1 with periodic b.c.
im = np.arange(N) - 1  
im[0] = N-1          # im = i-1 with periodic b.c.

#FTCS
for istep in range(int(nstep)) :

  #* Compute the flow = (Density)*(Velocity)
  Flow[:] = rho[:] * (v_max*(1 - rho[:]/rho_max))
  
  rho[:] = rho[:] - coeff*( Flow[ip] - Flow[im] )
  if (istep%1 == 0):
    a = np.copy(rho)
    ys = np.ones (N) *(istep)
    a = np.copy (rho)
    #plt.plot (xs, ys, a, '-k')
    #plt.plot (xs, ys, a, lw = 3)
    plt.plot (xs, a, lw = 3)

fig, ax = plt.subplots(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.tick_params(axis="z", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho1 = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho1[i] = rho_max     # Max density in the square pulse

rho1[int(N/2)] = rho_max/2   # Try running without this line


for istep in range(int(nstep)) :

  #* Compute the flow = (Density)*(Velocity)
  Flow[:] = rho1[:] * (v_max*(1 - rho1[:]/rho_max))
  
  rho1[:] = rho1[:] - coeff*( Flow[ip] - Flow[im] )
  if (istep%1 == 0): #graphing frequency
    a = np.copy(rho1)
    ys = np.ones (N) *(istep)
    #plt.plot (xs, ys, a, '-k')
    plt.plot (xs, ys, a, lw = 3)
    #plt.plot (xs, rho, lw = 3)

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

N = 80        #Grid points
L = 400.      # System size (meters)
h = L/N       # Grid spacing for periodic boundary conditions
v_max = 25.   # Maximum car speed (m/s)
tau = 0.1
nstep = 80
coeff = tau/(2*h) 
xs = np.arange (0, 80, 1)

rho_max = 1.0                   # Maximum density
Flow_max = 0.25*rho_max*v_max   # Maximum Flow
Flow = np.empty(N)
cp = np.empty(N);  cm = np.empty(N)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho[i] = rho_max     # Max density in the square pulse

rho[int(N/2)] = rho_max/2   # Try running without this line


fig, ax = plt.subplots(figsize=(16,9))
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Boundary conditions of constant rho
iv = np.arange(N-2) + 1
cp = np.zeros (N)
cn = np.zeros (N)

#FTCS
for istep in range(int(nstep)) :

  #* Compute the flow = (Density)*(Velocity)
  Flow[:] = rho[:] * (v_max*(1 - rho[:]/rho_max))
  
  rho[:] = rho[:] - coeff*( Flow[ip] - Flow[im] )
  if (istep%2 == 0):
    a = np.copy(rho)
    ys = np.ones (N) *(istep)
    a = np.copy (rho)
    #plt.plot (xs, ys, a, '-k')
    #plt.plot (xs, ys, a, lw = 3)
    plt.plot (xs, a, lw = 3)

fig, ax = plt.subplots(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.tick_params(axis="z", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho1 = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho1[i] = rho_max     # Max density in the square pulse

rho1[int(N/2)] = rho_max/2   # Try running without this line


for istep in range(int(nstep)) :

  #* Compute the flow = (Density)*(Velocity)
  Flow[:] = rho1[:] * (v_max*(1 - rho1[:]/rho_max))
  
  rho1[:] = rho1[:] - coeff*( Flow[ip] - Flow[im] )
  if (istep%3==0): #graphing frequency
    a = np.copy(rho1)
    ys = np.ones (N) *(nstep-istep)
    #plt.plot (xs, ys, a, '-k')
    plt.plot (xs, ys, a, lw = 3)
    #plt.plot (xs, rho, lw = 3)

# %% [markdown]
# ####**Possível solução: método de Lax - Wendroff**

# %% [markdown]
# Este método consiste em partir da expressão de Taylor, considerando os termos de 1a ordem em i e os de 2a ordem em i+1/2.
# Partimos da expansão de Taylor
#
# #$$ \rho(x, t + \delta t) = \rho(x, t) + \delta t \frac{\partial \rho}{\partial t} + \frac{\delta t^2}{2} \frac{\partial^2 \rho}{\partial t^2} + O(\delta t ^3) $$
# Descartamos os termos de ordem $\delta t ^3$ ou mais. A primeira derivada é obtida da equação original
# #$$\frac{\partial \rho}{\partial t} = - c(\rho)\frac{\partial \rho}{\partial x} $$
# Tomando a 2a derivada:
# #$$\frac{\partial^2 \rho}{\partial t^2} = - \frac{\partial}{\partial x} \frac{\partial ( c(\rho) \rho)}{\partial t}$$
# Mas
# #$$ \frac{\partial (c(\rho) \rho)}{\partial t} = \frac{\partial \rho}{\partial t} \frac {\partial (c\rho) \rho }{\partial \rho} $$
#
# Assim, temos que
#
# #$$ \rho(x, t + \delta t) = \rho(x, t) - c(\rho)\frac{\partial \rho}{\partial x}\delta t   + \frac{\partial \rho}{\partial t} \frac {\partial (c\rho) \rho }{\partial \rho}  \frac{\delta t^2}{2}+ O(\delta t ^3) $$
#
# Seja $c(\rho)\rho := F $ o fluxo de $\rho$ e $F'$ a derivada do fluxo em função de $\rho$. Discretizando com o termo de 2a ordem medido em i +-1/2 temos
#
# #$$\rho^{n+1}_{i} = \rho^{n}_i - \frac{\tau}{2h}(F^{n}_{i+1} - F^{n}_{i-1}) + \frac {\delta t^2}{2 h^2}[F'^{n}_{ì+\frac{1}{2}}(F^{n}_{i+1} - F^{n}_{i}) - F'^{n}_{i-\frac{1}{2}}(F^{n}_{i+1} - F^{n}_{i})] $$

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

N = 80        #Grid points
L = 400.      # System size (meters)
h = L/N       # Grid spacing for periodic boundary conditions
v_max = 25.   # Maximum car speed (m/s)
tau = 0.2
nstep = 120
coefflw = tau**2/(2*h**2)  # Coefficient used by Lax-Wendroff


rho_max = 1.0                   # Maximum density
Flow_max = 0.25*rho_max*v_max   # Maximum Flow
Flow = np.empty(N)
cp = np.empty(N);  cm = np.empty(N)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho[i] = rho_max     # Max density in the square pulse

rho[int(N/2)] = rho_max/2   # Try running without this line


fig, ax = plt.subplots(figsize=(16,9))
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Use periodic boundary conditions
ip = np.arange(N) + 1  
ip[N-1] = 0          # ip = i+1 with periodic b.c.
im = np.arange(N) - 1  
im[0] = N-1          # im = i-1 with periodic b.c.

#Lax-Wendroff method.
for istep in range(int(nstep)) :
    Flow[:] = rho[:] * (v_max*(1 - rho[:]/rho_max))

    cp[:] = v_max*(1 - (rho[ip]+rho[:])/rho_max);
    cm[:] = v_max*(1 - (rho[:]+rho[im])/rho_max);
    rho[:] = rho[:] - coeff*( Flow[ip] - Flow[im] ) + coefflw*(cp[:]*(Flow[ip]-Flow[:]) - cm[:]*(Flow[:]-Flow[im]) )
    if (istep%1 == 0):
      ys = np.ones (N) *(istep)
      a = np.copy (rho)
    #plt.plot (xs, ys, a, '-k')
    #plt.plot (xs, ys, a, lw = 3)
      plt.plot (xs, a, lw = 3)

fig, ax = plt.subplots(figsize=(16,9))
ax = fig.add_subplot(111, projection='3d')
ax.tick_params(axis="x", labelsize=20)
ax.tick_params(axis="y", labelsize=20)
ax.tick_params(axis="z", labelsize=20)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.spines['right'].set_linewidth(2)

# Initial condition is a square pulse from x = -L/4 to x = 0
rho = np.zeros(N)
for i in range(int(N/4),int(N/2)) :
    rho[i] = rho_max     # Max density in the square pulse

rho[int(N/2)] = rho_max/2   # Try running without this line


for istep in range(int(nstep)) :
  Flow[:] = rho[:] * (v_max*(1 - rho[:]/rho_max))

  cp[:] = v_max*(1 - (rho[ip]+rho[:])/rho_max);
  cm[:] = v_max*(1 - (rho[:]+rho[im])/rho_max);
  rho[:] = rho[:] - coeff*( Flow[ip] - Flow[im] ) + coefflw*(cp[:]*(Flow[ip]-Flow[:]) - cm[:]*(Flow[:]-Flow[im]) )
  if (istep%3==0):
    ys = np.ones (N) *(nstep-istep)
    a = np.copy (rho)
    #plt.plot (xs, ys, a, '-k')
    plt.plot (xs, ys, a, lw = 3)
    #plt.plot (xs, rho, lw = 3)
